# %%
import pandas as pd
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked',)).History will not be written to the database.

# %%
importance = pd.read_csv("../output/exp0_+address_poisson_outlin_3class+3meta_colsample4_floorrent+word_out2_people_num7+ekiuserate_kyori/feature_importances.csv")

# %%
pd.set_option('display.max_rows', 500)
importance.groupby("feature").mean().sort_values(by="gain", ascending=False)
# Out:
#                                   gain  split  fold
# feature
# out                       2.145668e+09  316.2   2.0
# 平均的な賃料相場_階数               1.633011e+09  714.4   2.0
# 平均的な賃料相場                  7.768367e+08  465.2   2.0
# 平均的な賃料相場_階数_方角            3.847413e+08  430.2   2.0
# 平均的な賃料相場_方角               3.493129e+08  401.8   2.0
# ...                                ...    ...   ...
# 間取りtypemin_of_一戸建て        0.000000e+00    0.0   2.0
# 間取りtypemin_of_定期借家        0.000000e+00    0.0   2.0
# 間取りtypemin_of_所在_区        0.000000e+00    0.0   2.0
# 間取りtypestd_of_cat_int間取り  0.000000e+00    0.0   2.0
# 月極駐車場                     0.000000e+00    0.0   2.0
#
# [1008 rows x 3 columns]

# %%
(200000**2)/(20000**2)
# Out:
# 100.0

# %%
(50000*2)
# Out:
# 100000

# %%
importance[importance["feature"].str.contains("people")]
# Out:
#                   feature          gain  split  fold
# 979              0_people  5.273279e+04     20     0
# 980              1_people  1.700914e+05     73     0
# 981              2_people  2.941825e+05     96     0
# 982           mean_people  1.445375e+05     64     0
# 983            max_people  3.631554e+05     49     0
# 984            min_people  4.505524e+05     70     0
# 985            std_people  2.453324e+05    109     0
# 986        people/meter_0  3.872777e+06    104     0
# 987        people/meter_1  5.477483e+05    119     0
# 988        people/meter_2  3.140599e+05    127     0
# 989   mean_people/meter_0  8.705499e+06    156     0
# 990    max_people/meter_0  5.054900e+06    133     0
# 991    min_people/meter_0  1.734797e+05     87     0
# 992    std_people/meter_0  8.252868e+05    139     0
# 1987             0_people  2.489577e+05     40     1
# 1988             1_people  2.369485e+05    114     1
# 1989             2_people  2.072900e+05    129     1
# ...
